-- %%
%sql
SHOW STORAGE CREDENTIALS

-- %%
use catalog circuitbox

-- %%
%sql
CREATE EXTERNAL LOCATION IF NOT EXISTS dea_course_ext_dl_circuitbox
URL 'abfss://circuitbox@deacoursedlsa.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL dea_course_ext_sc)
COMMENT 'external location for circuitbox'

-- %%
%sql
CREATE CATALOG IF NOT EXISTS circuitbox
      MANAGED LOCATION 'abfss://circuitbox@deacoursedlsa.dfs.core.windows.net/'
      COMMENT 'catalog for DLT demo'

-- %%
SHOW CATALOGS

-- %%
USE CATALOG circuitbox

-- %%
CREATE SCHEMA IF NOT EXISTS landing
      MANAGED LOCATION 'abfss://circuitbox@deacoursedlsa.dfs.core.windows.net/landing'
      COMMENT 'schema for raw data';

CREATE SCHEMA IF NOT EXISTS deltalake
      MANAGED LOCATION 'abfss://circuitbox@deacoursedlsa.dfs.core.windows.net/deltalake'
      COMMENT 'schema for processed data';

-- %% [markdown]
-- CREATE SCHEMA IF NOT EXISTS bronze
--       MANAGED LOCATION 'abfss://circuitbox@deacoursedlsa.dfs.core.windows.net/bronze'
--       COMMENT 'schema for processed data';
--
-- CREATE SCHEMA IF NOT EXISTS silver
--       MANAGED LOCATION 'abfss://circuitbox@deacoursedlsa.dfs.core.windows.net/silver'
--       COMMENT 'schema for processed data';
--
-- CREATE SCHEMA IF NOT EXISTS gold
--       MANAGED LOCATION 'abfss://circuitbox@deacoursedlsa.dfs.core.windows.net/gold'
--       COMMENT 'schema for processed data';

-- %%
SHOW SCHEMAS

-- %%
USE CATALOG circuitbox;
USE SCHEMA landing;

-- %% [markdown]
-- ### kEY WORDS BELOW:
-- - "EXTERNAL" VOLUME
-- - "LOCATION"

-- %%
CREATE EXTERNAL VOLUME IF NOT EXISTS operational_data
      LOCATION 'abfss://circuitbox@deacoursedlsa.dfs.core.windows.net/landing/operational_data'
      COMMENT 'volume for operational data'
